# %%
# value assignment
w <- 0
x <- 1
y <- 2
z <- 3
param_p <- 'abc'

# %%
# Input name list
library(dplyr)
param_a = '`'
print(w)
names <- c('Alice', 'Bob')

# %%
# Process name list
library(readr)
library(stringr)
for (name in names) {
  print(paste0('Hello, ', name))
}
t <- x + y
print(Sys.getenv())
print(param_p)

# %%
# print
print(t)
print(param_a)
